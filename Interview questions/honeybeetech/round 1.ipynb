# %% [markdown]
# Name': ['Alice', 'bob', 'Alice', None],
#     'Score': [95, 85, 95, 90]
# ----remove duplicate and NULL

# %%
l1 = ['Alice', 'bob', 'Alice', None]
l2 = [95, 85, 95, 90]

# %%
set_1 = set(l1)
set_2 = set(l2)

# %%
set_1
# Out:
# {'Alice', None, 'bob'}

# %%
l1_modified = list(set_1)

# %%
set_2
# Out:
# {85, 90, 95}

# %%
l1_modified
# Out:
# [None, 'Alice', 'bob']

# %%
l1_modified.pop()
# Out:
# 'bob'

# %%
l1_modified
# Out:
# [None, 'Alice']

# %%
l1_modified.remove(None)

# %%
l1_modified
# Out:
# ['Alice', 'bob']

# %%
l2_modified = list(set_2)

# %%
print(l1_modified)
print(l2_modified)
# Out:
# ['Alice', 'bob']
# [90, 85, 95]

# %%
import pandas as pd
df = pd.DataFrame({
    'Name': ['Alice', 'bob', 'Alice', None], 'Score': [95, 85, 95, 90]
})

# %%
df
# Out:
#     Name  Score
# 0  Alice     95
# 1    bob     85
# 2  Alice     95
# 3   None     90

# %%
df = df.dropna().drop_duplicates()

# %%
df
# Out:
#     Name  Score
# 0  Alice     95
# 1    bob     85
